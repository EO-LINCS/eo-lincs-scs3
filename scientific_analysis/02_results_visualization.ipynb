# %% [markdown]
# # Data visualization of the scientific results

# %% [markdown]
# **Description/Explanations:** Describe what will be shown in this notebook.
#
#
# -------------------------------------------------------------

# %% [markdown]
# ## Imports
#
# Let's import everything we need:
